# %%
import pandas as pd
import numpy as np

# %%
data_treatments = pd.read_csv("treatments.csv")
data_treatments
# Out:
#      Unnamed: 0           brand  \
# 0             0         Clarins
# 1             1  Drunk Elephant
# 2             2  Drunk Elephant
# 3             3  Drunk Elephant
# 4             4    SUNDAY RILEY
# ..          ...             ...
# 572         572       BeautyBio
# 573         573  The Inkey List
# 574         574     Dermalogica
# 575         575    AMOREPACIFIC
# 576         576  The Inkey List
#
#                                                   name price  n_of_reviews  \
# 0        Double Serum Complete Age Control Concentrate    89           391
# 1                          C-Firma Vitamin C Day Serum    80          1000
# 2                           TLC Sukari Babyfacial Mask    80          1000
# 3                T.L.C. Framboos™ Glycolic Night Serum    90          1000
# 4          Good Genes All-In-One Lactic Acid Treatment   158          2000
# ..                                                 ...   ...           ...
# ...

# %%
data_treatments.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0           brand  \
# 0             0         Clarins
# 1             1  Drunk Elephant
# 2             2  Drunk Elephant
# 3             3  Drunk Elephant
# 4             4    SUNDAY RILEY
# ..          ...             ...
# 572         572       BeautyBio
# 573         573  The Inkey List
# 574         574     Dermalogica
# 575         575    AMOREPACIFIC
# 576         576  The Inkey List
#
#                                                   name price  n_of_reviews  \
# 0        Double Serum Complete Age Control Concentrate    89           391
# 1                          C-Firma Vitamin C Day Serum    80          1000
# 2                           TLC Sukari Babyfacial Mask    80          1000
# 3                T.L.C. Framboos™ Glycolic Night Serum    90          1000
# 4          Good Genes All-In-One Lactic Acid Treatment   158          2000
# ..                                                 ...   ...           ...
# ...
