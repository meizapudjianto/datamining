# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('treatments.csv')
data
# Out:
#      Unnamed: 0           brand  \
# 0             0         Clarins
# 1             1  Drunk Elephant
# 2             2  Drunk Elephant
# 3             3  Drunk Elephant
# 4             4    SUNDAY RILEY
# ..          ...             ...
# 572         572       BeautyBio
# 573         573  The Inkey List
# 574         574     Dermalogica
# 575         575    AMOREPACIFIC
# 576         576  The Inkey List
#
#                                                   name price  n_of_reviews  \
# 0        Double Serum Complete Age Control Concentrate    89           391
# 1                          C-Firma Vitamin C Day Serum    80          1000
# 2                           TLC Sukari Babyfacial Mask    80          1000
# 3                T.L.C. Framboos™ Glycolic Night Serum    90          1000
# 4          Good Genes All-In-One Lactic Acid Treatment   158          2000
# ..                                                 ...   ...           ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     577 non-null    int64
#  1   brand          577 non-null    object
#  2   name           577 non-null    object
#  3   price          577 non-null    object
#  4   n_of_reviews   577 non-null    int64
#  5   n_of_loves     577 non-null    int64
#  6   review_score   577 non-null    float64
#  7   size           577 non-null    object
#  8   clean_product  577 non-null    int64
#  9   category       577 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 45.2+ KB

# %%
data.head()
# Out:
#    Unnamed: 0           brand                                           name  \
# 0           0         Clarins  Double Serum Complete Age Control Concentrate
# 1           1  Drunk Elephant                    C-Firma Vitamin C Day Serum
# 2           2  Drunk Elephant                     TLC Sukari Babyfacial Mask
# 3           3  Drunk Elephant          T.L.C. Framboos™ Glycolic Night Serum
# 4           4    SUNDAY RILEY    Good Genes All-In-One Lactic Acid Treatment
#
#   price  n_of_reviews  n_of_loves  review_score     size  clean_product  \
# 0    89           391       16293        4.0997     1 oz              0
# 1    80          1000      135964        4.1097     1 oz              1
# 2    80          1000      178783        4.4283  1.69 oz              1
# 3    90          1000      144421        4.2968     1 oz              1
# 4   158          2000      154923        4.3046   1.7 oz              0
#
#       category
# 0  Face Serums
# 1  Face Serums
# 2   Face Masks
# ...

# %%
summary = data.describe()
print(summary)
# Out:
#        Unnamed: 0  n_of_reviews     n_of_loves  review_score  clean_product
# count  577.000000    577.000000     577.000000    577.000000     577.000000
# mean   288.000000    230.173310   13876.844021      4.022682       0.157712
# std    166.709828    432.857657   25385.285476      1.013341       0.364787
# min      0.000000      0.000000       0.000000      0.000000       0.000000
# 25%    144.000000     12.000000    1625.000000      3.950200       0.000000
# 50%    288.000000     64.000000    5009.000000      4.229400       0.000000
# 75%    432.000000    265.000000   13571.000000      4.483900       0.000000
# max    576.000000   5000.000000  235409.000000      5.000000       1.000000

# %%
plt.hist(data['category'])
plt.show()

# %%
plt.hist(data['size'])
plt.show()

# %%
plt.hist(data['brand'])
plt.show()

# %%
sns.boxplot(x=data['clean_product'])
plt.show()

# %%
sns.boxplot(x=data['review_score'])
plt.show()

# %%
sns.boxplot(x=data['n_of_loves'])
plt.show()

# %%
plt.scatter(data['brand'], data['price'])
plt.show()

# %%
plt.scatter(data['name'], data['category'])
plt.show()
